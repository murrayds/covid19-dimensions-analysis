# %%
import pandas as pd
import pandas_gbq
import tqdm

import logging
logger = logging.getLogger('pandas_gbq')
logger.setLevel(logging.DEBUG)
logger.addHandler(logging.StreamHandler())

# Project ID
project_id = "ccnr-success"

# %% [markdown]
# What are the leading research organizations pursuing any COVID-19 research? Who are the leading research organizations pursuing COVID-19 vaccine research?

# %%
sql = """
select 
  counts.id, 
  counts.pubcount,  
  orgs.name,
  orgs.address.country as country,
  orgs.address.latitude as latitude,
  orgs.address.longitude as longitude
from
(
  select 
    orgs.id,
    count(orgs.id) as pubcount
  from (
    SELECT id, orgid
    FROM `covid-19-dimensions-ai.data.publications`,
    UNNEST(research_orgs) orgid
    WHERE type = "article"  -- limit to research articles
    AND ('COVID-19' in UNNEST(concepts.concept) or "new coronavirus" in UNNEST(concepts.concept) or "SARS-CoV-2" in UNNEST(concepts.concept)
          OR 'ncov' in UNNEST(concepts.concept) or "novel coronavirus" in UNNEST(concepts.concept) or "2019-ncov" in UNNEST(concepts.concept)
          OR "severe acute respiratory syndrome coronavirus" in UNNEST(concepts.concept) or 'coronavirus disease 2019' in UNNEST(concepts.concept)
          OR REGEXP_CONTAINS(title.preferred, r"covid-19|new coronavirus|novel coronavirus|sars-cov-2|2019-ncov|hcov|severe acute respiratory syndrome coronavirus|coronavirus disease 2019"))
  ) as pubs 
  left join `covid-19-dimensions-ai.data.grid` as orgs on pubs.orgid = orgs.id
  group by orgs.id
) as counts
left join `covid-19-dimensions-ai.data.grid` as orgs on counts.id = orgs.id
order by pubcount DESC

"""
df = pandas_gbq.read_gbq(sql, project_id=project_id)
df
# Out:
# Requesting query...
# Requesting query...
# Query running...
# Query running...
# Job ID: 776bead1-0dd4-4a35-94f8-27f019a0b2a7
# Job ID: 776bead1-0dd4-4a35-94f8-27f019a0b2a7
# Query done.
# Cache hit.
#
# Query done.
# Cache hit.
#
# Downloading: 100%|███████████████████| 22202/22202 [00:02<00:00, 10604.49rows/s]
# Got 22202 rows.
#
# Got 22202 rows.
#                   id  pubcount                                           name  \
# 0      grid.38142.3c      3298                             Harvard University
# 1      grid.33199.31      1922  Huazhong University of Science and Technology
# 2      grid.17063.33      1869                          University of Toronto
# 3      grid.21107.35      1860                       Johns Hopkins University
# 4        grid.4991.5      1824                           University of Oxford
# ...              ...       ...                                            ...
# 22197  grid.490170.b         1            Fuling Center Hospital of Chongqing
# 22198  grid.459318.2         1       Australian College of Applied Psychology
# 22199  grid.483908.e         1           Shanghai Hospital Development Center
# 22200  grid.465956.d         1                            LUCA School of Arts
# 22201  grid.427946.a         1                       Berklee College of Music
#
#               country   latitude   longitude
# 0       United States  42.377052  -71.116653
# 1               China  30.508183  114.414742
# 2              Canada  43.661667  -79.394997
# 3       United States  39.328888  -76.620277
# 4      United Kingdom  51.753437   -1.254010
# ...               ...        ...         ...
# 22197           China  29.709438  107.395531
# 22198       Australia -33.865334  151.205322
# 22199           China  31.238739  121.455162
# 22200         Belgium  50.861362    4.367237
# 22201   United States  42.347515  -71.089615
#
# [22202 rows x 6 columns]

# %%
# Maybe show differences in rank between these two? Some sort of flow-like graph?
sql = """
select 
  counts.id, 
  counts.pubcount,  
  orgs.name,
  orgs.address.country as country,
  orgs.address.latitude as latitude,
  orgs.address.longitude as longitude
from
(
  select 
    orgs.id,
    count(orgs.id) as pubcount
  from (
    SELECT id, orgid
    FROM `covid-19-dimensions-ai.data.publications`,
    UNNEST(research_orgs) orgid
    where type = 'article'
    AND ('COVID-19' in UNNEST(concepts.concept) or "new coronavirus" in UNNEST(concepts.concept) or "SARS-CoV-2" in UNNEST(concepts.concept)
          OR 'ncov' in UNNEST(concepts.concept) or "novel coronavirus" in UNNEST(concepts.concept) or "2019-ncov" in UNNEST(concepts.concept)
          OR "severe acute respiratory syndrome coronavirus" in UNNEST(concepts.concept) or 'coronavirus disease 2019' in UNNEST(concepts.concept)
          OR REGEXP_CONTAINS(title.preferred, r"covid-19|new coronavirus|novel coronavirus|sars-cov-2|2019-ncov|hcov|severe acute respiratory syndrome coronavirus|coronavirus disease 2019"))
  ) as pubs 
  left join `covid-19-dimensions-ai.data.grid` as orgs on pubs.orgid = orgs.id
  group by orgs.id
) as counts
left join `covid-19-dimensions-ai.data.grid` as orgs on counts.id = orgs.id
order by pubcount DESC

"""
df = pandas_gbq.read_gbq(sql, project_id=project_id)
df
# Out:
# Requesting query...
# Requesting query...
# Query running...
# Query running...
# Job ID: 58ca3738-d54e-486f-bf7b-7bb219983c5b
# Job ID: 58ca3738-d54e-486f-bf7b-7bb219983c5b
# Query done.
# Processed: 731.0 MB Billed: 731.0 MB
# Query done.
# Processed: 731.0 MB Billed: 731.0 MB
# Standard price: $0.00 USD
#
# Standard price: $0.00 USD
#
# Downloading: 100%|████████████████████| 22202/22202 [00:02<00:00, 8847.99rows/s]
# Got 22202 rows.
#
# Got 22202 rows.
#
# Total time taken 12.06 s.
# Finished at 2022-04-27 12:06:57.
# Total time taken 12.06 s.
# Finished at 2022-04-27 12:06:57.
#                   id  pubcount                                           name  \
# 0      grid.38142.3c      3298                             Harvard University
# 1      grid.33199.31      1922  Huazhong University of Science and Technology
# 2      grid.17063.33      1869                          University of Toronto
# 3      grid.21107.35      1860                       Johns Hopkins University
# 4        grid.4991.5      1824                           University of Oxford
# ...              ...       ...                                            ...
# 22197  grid.441677.7         1       Universidad Nacional José María Arguedas
# 22198  grid.263652.6         1                     Sinclair Community College
# 22199  grid.454577.0         1                          Granite State College
# 22200  grid.488859.0         1           L’Institut du Cancer Courlancy Reims
# 22201  grid.449948.c         1        Wenzao Ursuline University of Languages
#
#               country   latitude   longitude
# 0       United States  42.377052  -71.116653
# 1               China  30.508183  114.414742
# 2              Canada  43.661667  -79.394997
# 3       United States  39.328888  -76.620277
# 4      United Kingdom  51.753437   -1.254010
# ...               ...        ...         ...
# 22197            Peru -13.656001  -73.387886
# 22198   United States  39.757004  -84.198471
# 22199   United States  43.192921  -71.526978
# 22200          France  49.245121    4.018232
# 22201          Taiwan  22.671715  120.318970
#
# [22202 rows x 6 columns]

# %%
# Maybe show differences in rank between these two? Some sort of flow-like graph?
sql = """
select 
  counts.id, 
  counts.pubcount,  
  orgs.name,
  orgs.address.country as country,
  orgs.address.latitude as latitude,
  orgs.address.longitude as longitude
from
(
  select 
    orgs.id,
    count(orgs.id) as pubcount
  from (
    SELECT id, orgid
    FROM `covid-19-dimensions-ai.data.publications`,
    UNNEST(research_orgs) orgid
    WHERE type = "article"  -- limit to research articles
    AND ('COVID-19' in UNNEST(concepts.concept) or "new coronavirus" in UNNEST(concepts.concept) or "SARS-CoV-2" in UNNEST(concepts.concept)
          OR 'ncov' in UNNEST(concepts.concept) or "novel coronavirus" in UNNEST(concepts.concept) or "2019-ncov" in UNNEST(concepts.concept)
          OR "severe acute respiratory syndrome coronavirus" in UNNEST(concepts.concept) or 'coronavirus disease 2019' in UNNEST(concepts.concept)
          OR REGEXP_CONTAINS(title.preferred, r"covid-19|new coronavirus|novel coronavirus|sars-cov-2|2019-ncov|hcov|severe acute respiratory syndrome coronavirus|coronavirus disease 2019"))
  ) as pubs 
  left join `covid-19-dimensions-ai.data.grid` as orgs on pubs.orgid = orgs.id
  group by orgs.id
) as counts
left join `covid-19-dimensions-ai.data.grid` as orgs on counts.id = orgs.id
order by pubcount DESC

"""
df = pandas_gbq.read_gbq(sql, project_id=project_id)
df
# Out:
# Requesting query...
# Requesting query...
# Query running...
# Query running...
# Job ID: 7cf07ede-1545-4694-a6cd-b2ce29c48f60
# Job ID: 7cf07ede-1545-4694-a6cd-b2ce29c48f60
# Query done.
# Cache hit.
#
# Query done.
# Cache hit.
#
# Downloading: 100%|███████████████████| 22202/22202 [00:01<00:00, 13149.31rows/s]
# Got 22202 rows.
#
# Got 22202 rows.
#                   id  pubcount                                           name  \
# 0      grid.38142.3c      3298                             Harvard University
# 1      grid.33199.31      1922  Huazhong University of Science and Technology
# 2      grid.17063.33      1869                          University of Toronto
# 3      grid.21107.35      1860                       Johns Hopkins University
# 4        grid.4991.5      1824                           University of Oxford
# ...              ...       ...                                            ...
# 22197  grid.490170.b         1            Fuling Center Hospital of Chongqing
# 22198  grid.459318.2         1       Australian College of Applied Psychology
# 22199  grid.483908.e         1           Shanghai Hospital Development Center
# 22200  grid.465956.d         1                            LUCA School of Arts
# 22201  grid.427946.a         1                       Berklee College of Music
#
#               country   latitude   longitude
# 0       United States  42.377052  -71.116653
# 1               China  30.508183  114.414742
# 2              Canada  43.661667  -79.394997
# 3       United States  39.328888  -76.620277
# 4      United Kingdom  51.753437   -1.254010
# ...               ...        ...         ...
# 22197           China  29.709438  107.395531
# 22198       Australia -33.865334  151.205322
# 22199           China  31.238739  121.455162
# 22200         Belgium  50.861362    4.367237
# 22201   United States  42.347515  -71.089615
#
# [22202 rows x 6 columns]

# %%
metrics = ["total_times_cited", "total_altmetrics_score", "avg_gield_citation_ratio"]
conditions = ["", "and auth.corresonding = True"]
country = ["", "and 'USA' in auth.raw_affiliation"] # Be sure to add this too—compare local (US) w/ Global leaders
sql = """
WITH top_researchers AS (
  SELECT * FROM (
      SELECT
        auth.researcher_id,
        ANY_VALUE(auth.first_name) as first_name,
        ANY_VALUE(auth.last_name) as last_name,
        COUNT(DISTINCT(pubs.id)) as pub_count,
        SUM(altmetrics.score) as total_altmetrics_score,
        SUM(metrics.times_cited) as total_times_cited,
        AVG(metrics.field_citation_ratio) as avg_field_citation_ratio,
      FROM `covid-19-dimensions-ai.data.publications` as pubs,
      UNNEST(authors) auth
      WHERE type = "article" AND researcher_id is not NULL {}
      AND ('COVID-19' in UNNEST(concepts.concept) or "new coronavirus" in UNNEST(concepts.concept) or "SARS-CoV-2" in UNNEST(concepts.concept)
           OR 'ncov' in UNNEST(concepts.concept) or "novel coronavirus" in UNNEST(concepts.concept) or "2019-ncov" in UNNEST(concepts.concept)
           OR "severe acute respiratory syndrome coronavirus" in UNNEST(concepts.concept) or 'coronavirus disease 2019' in UNNEST(concepts.concept)
           OR REGEXP_CONTAINS(title.preferred, r"covid-19|new coronavirus|novel coronavirus|sars-cov-2|2019-ncov|hcov|severe acute respiratory syndrome coronavirus|coronavirus disease 2019"))
      GROUP BY researcher_id
      ORDER BY {} DESC
    ) 
    WHERE pub_count > 4 -- keep only productive authors, no single-paper wonders
    LIMIT 50
),
researcher_orgs AS (
  -- Get the most frequent affiliation of the researcher
  select researchers.*, orgs.name as org_name, orgs.address.country as org_country, orgs.address.city as org_city
  from (
    SELECT top.researcher_id, org_id, COUNT(DISTINCT(p.id)) as org_count
    FROM `covid-19-dimensions-ai.data.publications` as p
    INNER JOIN top_researchers as top on top.researcher_id in UNNEST(p.authors.researcher_id)
    CROSS JOIN UNNEST(p.authors) auth,
    unnest(auth.grid_ids) as org_id
    WHERE TRUE
    group by top.researcher_id, org_id
    QUALIFY ROW_NUMBER() OVER (PARTITION BY top.researcher_id ORDER BY org_count DESC) = 1
  ) as researchers
  left join `covid-19-dimensions-ai.data.grid` as orgs on orgs.id = researchers.org_id
),
researcher_concepts AS (
  -- Get the concepts associated with papers they published
  SELECT top.researcher_id, ARRAY_CONCAT_AGG(concepts) as concepts
  FROM `covid-19-dimensions-ai.data.publications` as p
  INNER JOIN top_researchers as top on top.researcher_id in UNNEST(p.authors.researcher_id)
  group by top.researcher_id
),
researcher_fields AS (
  -- determines the field of research code in which
  -- the researcher has most frequently authored papers
  SELECT top.researcher_id, for2.name, COUNT(DISTINCT p.id) as cat_count, 
  FROM `covid-19-dimensions-ai.data.publications` as p
  INNER JOIN top_researchers as top on top.researcher_id in UNNEST(p.authors.researcher_id)
  CROSS JOIN UNNEST(category_for.second_level.full) as for2
  WHERE TRUE
  group by top.researcher_id, for2.name
  QUALIFY ROW_NUMBER() OVER (PARTITION BY top.researcher_id ORDER BY cat_count DESC) = 1
)

select 
  top.*,
  fields.* except(cat_count, researcher_id),
  concepts.* except(researcher_id),
  orgs.* except(org_count, researcher_id)
from top_researchers as top
left join researcher_fields as fields on fields.researcher_id = top.researcher_id
left join researcher_concepts as concepts on concepts.researcher_id = top.researcher_id
left join researcher_orgs as orgs on orgs.researcher_id = top.researcher_id

""".format("and auth.corresponding = True", "pub_count")
df = pandas_gbq.read_gbq(sql, project_id=project_id)
df

# Rank by each metric for all
# GLobal, corresponidng authors only'
# US-only, all authorships
# US-only, correpsonding authors only
# Out:
# Requesting query...
# Requesting query...
# Query running...
# Query running...
# Job ID: 2dfcc20a-d9cd-4852-b80f-ee4a53d3c2e3
# Job ID: 2dfcc20a-d9cd-4852-b80f-ee4a53d3c2e3
# Query done.
# Processed: 1.3 GB Billed: 1.3 GB
# Query done.
# Processed: 1.3 GB Billed: 1.3 GB
# Standard price: $0.01 USD
#
# Standard price: $0.01 USD
#
# Downloading: 100%|████████████████████████████| 50/50 [00:06<00:00,  7.49rows/s]
# Got 50 rows.
#
# Got 50 rows.
#
# Total time taken 17.77 s.
# Finished at 2022-04-27 12:08:21.
# Total time taken 17.77 s.
# Finished at 2022-04-27 12:08:21.
#          researcher_id       first_name           last_name  pub_count  \
# 0     ur.0652735016.56        Kwok-Yung                Yuen         66
# 1     ur.0764344311.13             Nima              Rezaei         52
# 2    ur.01310657647.41         Giuseppe               Lippi         52
# 3    ur.01204711510.82       Alfonso J.   Rodriguez-Morales         50
# 4   ur.013163031217.47       Chia Siang                 Kow         50
# 5   ur.013145671557.48           Didier              Raoult         39
# 6    ur.01304412561.27           Daihai                  He         38
# 7    ur.01072733407.19        George F.                 Gao         38
# 8   ur.014140240160.25        Rujittika  Mungmunpuntipantip         37
# 9     ur.0716736562.19          Kuldeep               Dhama         37
# 10  ur.014251225337.11            Josef           Finsterer         35
# 11   ur.01143221111.34           Wenjie                 Tan         34
# 12  ur.016226163047.61            Shibo               Jiang         33
# 13    ur.0671423130.37             Beuy                Joob         32
# 14   ur.07453353357.09         Hongzhou                  Lu         32
# 15   ur.01264275476.71            Zheng               Zhang         30
# 16   ur.01036056662.14           Bikash               Medhi         29
# 17   ur.01170561375.70       Chung-Ying                 Lin         28
# 18    ur.0722405622.36         Xinghuan                Wang         28
# 19   ur.01041525526.29              Lei                 Liu         27
# 20  ur.010176701342.18         Nan-shan               Zhong         27
# 21   ur.01152513411.13  Brandon Michael               Henry         27
# 22    ur.0641123655.02              Bin                 Cao         27
# 23    ur.0744141225.67           Andree           Kurniawan         26
# 24    ur.0601533600.56     Mohammad Ali                Moni         26
# 25    ur.0713663251.48           Po-Ren               Hsueh         26
# 26    ur.0726001752.41         Jaffar A           Al-Tawfiq         25
# 27   ur.01307070654.05           Yu-Tao               Xiang         25
# 28  ur.010416750634.52          Jianwei                Wang         25
# 29    ur.0677500057.92          Susanna            Esposito         24
# 30  ur.012755213350.86   Gaber El-Saber              Batiha         24
# 31    ur.0644324362.10           Dan H.             Barouch         24
# 32    ur.0711767431.18        Dong-Qing                 Wei         24
# 33   ur.01025517744.05         Fu-Sheng                Wang         23
# 34   ur.01364774736.90              Lin                  Lu         23
# 35    ur.0700346637.11           Amir H             Pakpour         23
# 36    ur.0661266564.44   Awadhesh Kumar               Singh         22
# 37   ur.01347426606.33               Yu                  Hu         22
# 38   ur.01256375716.98              Ali    Gholamrezanezhad         22
# 39  ur.010375443771.36        Francesco             Ferrara         22
# 40   ur.01156362044.18           Ziad A              Memish         22
# 41    ur.0711257316.22          Hiroshi            Nishiura         21
# 42   ur.01362152061.09          Lanjuan                  Li         21
# 43  ur.011561470657.16   Mohammad Yasir               Essar         21
# 44   ur.01235147121.49        Pragya D.               Yadav         21
# 45  ur.013545476360.75         Sung-Han                 Kim         21
# 46   ur.01353360710.43          Youchun                Wang         20
# 47  ur.012321453367.61         Zheng-Li                 Shi         20
# 48   ur.01020211716.33           Manish               Kumar         20
# 49   ur.01072360377.18           Jincun                Zhao         20
#
#     total_altmetrics_score  total_times_cited  avg_field_citation_ratio  \
# 0                    31091              18262                200.379250
# 1                      335               2115                 29.191935
# 2                     1382               2735                 88.101111
# 3                     2186               3625                 80.814615
# 4                      463                190                  2.538182
# 5                    33340               6141                169.805882
# 6                     1108               2983                110.000000
# 7                     5606               3128                 92.529091
# 8                       18                 21                  4.990000
# 9                      893               1635                 48.973333
# 10                     693                 98                       NaN
# 11                   17963              30819                756.064375
# 12                    6208               3147                 63.707647
# 13                    1774                566                 22.102353
# 14                    1350               1686                 73.283529
# 15                   16553               7618                455.923333
# 16                     570                450                 11.207143
# 17                     294                722                 39.718571
# 18                   13891              21022                720.466364
# 19                   19704               7982                333.585625
# 20                    1385               1366                 69.231111
# 21                     682               3034                131.377222
# 22                   44413              49906               2625.340714
# 23                     526                688                 34.903333
# 24                     117                422                 20.756000
# 25                     967               5301                174.124211
# 26                     451                771                 33.265000
# 27                     398               1325                106.985714
# 28                   16798              34128               3065.781250
# 29                    2527                449                 25.446250
# 30                     204                196                  6.840000
# 31                    9338               2632                122.691667
# 32                     222                324                 23.414000
# 33                    3306               8047                439.240000
# 34                     657                576                 48.502000
# 35                     321               2334                212.593750
# 36                    1133               1759                 60.597222
# 37                     517               1530                 63.859000
# 38                     370                949                 36.785294
# 39                      84                298                  9.700000
# 40                     441                801                 33.316667
# 41                    6701               2578                140.818000
# 42                    1692               2219                 80.156667
# 43                     138                116                 15.320000
# 44                     858                480                 18.090000
# 45                    1916                495                 44.836667
# 46                    3477               2217                200.828000
# 47                   14237              17415               1082.085455
# 48                     131                602                 30.741667
# 49                    3282               1605                146.274000
#
#                                             name  \
# 0                           Medical Microbiology
# 1                              Clinical Sciences
# 2                              Clinical Sciences
# 3              Public Health and Health Services
# 4                              Clinical Sciences
# 5                              Clinical Sciences
# 6              Public Health and Health Services
# 7                                     Immunology
# 8                              Clinical Sciences
# 9                           Medical Microbiology
# 10                             Clinical Sciences
# 11                          Medical Microbiology
# 12                                    Immunology
# 13                             Clinical Sciences
# 14                             Clinical Sciences
# 15                                    Immunology
# 16                 Biochemistry and Cell Biology
# 17             Public Health and Health Services
# 18                             Clinical Sciences
# 19                             Clinical Sciences
# 20                             Clinical Sciences
# 21                             Clinical Sciences
# 22                             Clinical Sciences
# 23                             Clinical Sciences
# 24  Artificial Intelligence and Image Processing
# 25                          Medical Microbiology
# 26             Public Health and Health Services
# 27             Public Health and Health Services
# 28                          Medical Microbiology
# 29             Public Health and Health Services
# 30                             Clinical Sciences
# 31                                    Immunology
# 32                          Medical Microbiology
# 33                             Clinical Sciences
# 34             Public Health and Health Services
# 35             Public Health and Health Services
# 36                             Clinical Sciences
# 37                             Clinical Sciences
# 38                             Clinical Sciences
# 39                             Clinical Sciences
# 40             Public Health and Health Services
# 41             Public Health and Health Services
# 42                             Clinical Sciences
# 43             Public Health and Health Services
# 44                                    Immunology
# 45             Public Health and Health Services
# 46                                          None
# 47                          Medical Microbiology
# 48                     Environmental Engineering
# 49                          Medical Microbiology
#
#                                              concepts         org_id  \
# 0   [{'concept': 'COVID-19 patients', 'relevance':...  grid.194645.b
# 1   [{'concept': 'serological tests', 'relevance':...  grid.411705.6
# 2   [{'concept': 'laboratory abnormalities', 'rele...    grid.5611.3
# 3   [{'concept': 'COVID-19 vaccination', 'relevanc...  grid.441853.f
# 4   [{'concept': 'adverse clinical outcomes', 'rel...  grid.411729.8
# 5   [{'concept': 'SARS-CoV-2', 'relevance': 0.419}...  grid.483853.1
# 6   [{'concept': 'train transportation', 'relevanc...  grid.16890.36
# 7   [{'concept': 'COVID-19', 'relevance': 0.397}, ...  grid.458488.d
# 8   [{'concept': 'COVID-19 vaccine', 'relevance': ...  grid.440681.f
# 9   [{'concept': 'risk of infection', 'relevance':...  grid.417990.2
# 10  [{'concept': 'Neuro-COVID', 'relevance': 0.615...  grid.411249.b
# 11  [{'concept': 'BBIBP-CorV', 'relevance': 0.664}...  grid.419468.6
# 12  [{'concept': 'viral spike protein', 'relevance...    grid.8547.e
# 13  [{'concept': 'COVID-19 incidence', 'relevance'...  grid.440681.f
# 14  [{'concept': 'cytokine storm', 'relevance': 0....  grid.470110.3
# 15  [{'concept': 'monoclonal antibodies', 'relevan...  grid.263817.9
# 16  [{'concept': 'low-dose naltrexone', 'relevance...  grid.415131.3
# 17  [{'concept': 'problematic social media use', '...  grid.64523.36
# 18  [{'concept': 'risk factors', 'relevance': 0.61...  grid.413247.7
# 19  [{'concept': 'COVID-19 pathogenesis', 'relevan...  grid.410741.7
# 20  [{'concept': 'B cell receptor', 'relevance': 0...  grid.470124.4
# 21  [{'concept': 'SARS-CoV-2 serology testing', 'r...  grid.239573.9
# 22  [{'concept': 'reply', 'relevance': 0.065}, {'c...  grid.415954.8
# 23  [{'concept': 'autoimmune hemolytic anemia', 'r...  grid.443962.e
# 24  [{'concept': 'chronic obstructive pulmonary di...    grid.1005.4
# 25  [{'concept': 'COVID-19 patients', 'relevance':...  grid.19188.39
# 26  [{'concept': 'COVID-19 patients', 'relevance':...  grid.415305.6
# 27  [{'concept': 'mental health services', 'releva...  grid.437123.0
# 28  [{'concept': 'SARS-CoV-2', 'relevance': 0.587}...  grid.506261.6
# 29  [{'concept': 'routine pediatric vaccines', 're...  grid.10383.39
# 30  [{'concept': 'viral infection', 'relevance': 0...  grid.449014.c
# 31  [{'concept': 'antibody titers', 'relevance': 0...  grid.239395.7
# 32  [{'concept': 'Tick-Borne Encephalitis Virus', ...  grid.16821.3c
# 33  [{'concept': 'T cell activation', 'relevance':...  grid.488137.1
# 34  [{'concept': 'multivariable logistic regressio...  grid.11135.37
# 35  [{'concept': 'problematic social media use', '...  grid.118888.0
# 36  [{'concept': 'management of hyperglycemia', 'r...  grid.508044.d
# 37  [{'concept': 'severe COVID-19', 'relevance': 0...  grid.33199.31
# 38  [{'concept': 'ventilation-perfusion scan', 're...  grid.42505.36
# 39  [{'concept': 'COVID-19', 'relevance': 0.132}, ...  grid.425883.0
# 40  [{'concept': 'novel coronavirus', 'relevance':...  grid.189967.8
# 41  [{'concept': 'antimicrobial use density', 'rel...  grid.39158.36
# 42  [{'concept': 'subtomogram averaging', 'relevan...  grid.13402.34
# 43  [{'concept': 'meningitis outbreak', 'relevance...  grid.415422.4
# 44  [{'concept': 'respiratory virus detection', 'r...  grid.419672.f
# 45  [{'concept': 'ChAdOx1 nCoV-19 vaccine', 'relev...  grid.413967.e
# 46                                                 []           None
# 47                                                 []           None
# 48  [{'concept': 'SARS-CoV-2 RNA', 'relevance': 0....  grid.462384.f
# 49                                                 []           None
#
#                                              org_name    org_country  \
# 0                             University of Hong Kong          China
# 1               Tehran University of Medical Sciences           Iran
# 2                                University of Verona          Italy
# 3    Fundación Universitaria Autónoma De Las Américas       Colombia
# 4                    International Medical University       Malaysia
# 5                   Méditerranée Infection Foundation         France
# 6                    Hong Kong Polytechnic University          China
# 7                           Institute of Microbiology          China
# 8                     Dr. D.Y. Patil Vidyapeeth, Pune          India
# 9                Indian Veterinary Research Institute          India
# 10                    Federal University of São Paulo         Brazil
# 11  National Institute for Viral Disease Control a...          China
# 12                                   Fudan University          China
# 13                    Dr. D.Y. Patil Vidyapeeth, Pune          India
# 14             Shanghai Public Health Clinical Center          China
# 15      Southern University of Science and Technology          China
# 16  Post Graduate Institute of Medical Education a...          India
# 17                     National Cheng Kung University         Taiwan
# 18              Zhongnan Hospital of Wuhan University          China
# 19                   Shenzhen Third People’s Hospital          China
# 20  First Affiliated Hospital of Guangzhou Medical...          China
# 21      Cincinnati Children's Hospital Medical Center  United States
# 22                    China-Japan Friendship Hospital          China
# 23                          Pelita Harapan University      Indonesia
# 24                                        UNSW Sydney      Australia
# 25                         National Taiwan University         Taiwan
# 26         Saudi Aramco Medical Services Organization   Saudi Arabia
# 27                                University of Macau          China
# 28  Chinese Academy of Medical Sciences & Peking U...          China
# 29                                University of Parma          Italy
# 30                               Damanhour University          Egypt
# 31               Beth Israel Deaconess Medical Center  United States
# 32                      Shanghai Jiao Tong University          China
# 33                           People's Liberation Army          China
# 34                                  Peking University          China
# 35                               Jönköping University         Sweden
# 36                   GD Hospital & Diabetes Institute          India
# 37      Huazhong University of Science and Technology          China
# 38                  University of Southern California  United States
# 39                                   Regione Campania          Italy
# 40                                   Emory University  United States
# 41                                Hokkaido University          Japan
# 42                                Zhejiang University          China
# 43                             Punjab Medical College       Pakistan
# 44                     National Institute of Virology          India
# 45                                Asan Medical Center    South Korea
# 46                                               None           None
# 47                                               None           None
# 48         Indian Institute of Technology Gandhinagar          India
# 49                                               None           None
#
#         org_city
# 0      Hong Kong
# 1         Tehran
# 2         Verona
# 3       Medellín
# 4   Kuala Lumpur
# 5      Marseille
# 6      Hong Kong
# 7        Beijing
# 8           Pune
# 9       Bareilly
# 10     São Paulo
# 11       Beijing
# 12      Shanghai
# 13          Pune
# 14      Shanghai
# 15      Shenzhen
# 16    Chandigarh
# 17   Tainan City
# 18         Wuhan
# 19      Shenzhen
# 20     Guangzhou
# 21    Cincinnati
# 22       Beijing
# 23     Tangerang
# 24        Sydney
# 25        Taipei
# 26       Dhahran
# 27         Macao
# 28       Beijing
# 29         Parma
# 30      Damanhur
# 31        Boston
# 32      Shanghai
# 33       Beijing
# 34       Beijing
# 35     Jönköping
# 36       Kolkata
# 37         Wuhan
# 38   Los Angeles
# 39        Naples
# 40       Atlanta
# 41       Sapporo
# 42      Hangzhou
# 43    Faisalabad
# 44          Pune
# 45         Seoul
# 46          None
# 47          None
# 48   Gandhinagar
# 49          None

# %%
# Get the top publications
metrics = ["times_cited", "altmetrics_score", "field_citation_ratio"]
sql = """
select
    doi,
    title.preferred as pub_title,
    journal.title as journal_title,
    year, 
    volume,
    issue, 
    pages,
    altmetrics.score as altmetrics_score,
    metrics.times_cited,
    metrics.field_citation_ratio
  from `covid-19-dimensions-ai.data.publications`
  where type = "article"
  AND ('COVID-19' in UNNEST(concepts.concept) or "new coronavirus" in UNNEST(concepts.concept) or "SARS-CoV-2" in UNNEST(concepts.concept)
        OR 'ncov' in UNNEST(concepts.concept) or "novel coronavirus" in UNNEST(concepts.concept) or "2019-ncov" in UNNEST(concepts.concept)
        OR "severe acute respiratory syndrome coronavirus" in UNNEST(concepts.concept) or 'coronavirus disease 2019' in UNNEST(concepts.concept)
        OR REGEXP_CONTAINS(title.preferred, r"covid-19|new coronavirus|novel coronavirus|sars-cov-2|2019-ncov|hcov|severe acute respiratory syndrome coronavirus|coronavirus disease 2019"))
  order by {} DESC
  limit 5;
""".format("times_cited")
df = pandas_gbq.read_gbq(sql, project_id=project_id)
df

# Rank by each metric for all
# GLobal, corresponidng authors only'
# US-only, all authorships
# US-only, correpsonding authors only
# Out:
# Requesting query...
# Requesting query...
# Query running...
# Query running...
# Job ID: 8f2c6740-86ac-4b92-b20e-0f5a1fcdfaf2
# Job ID: 8f2c6740-86ac-4b92-b20e-0f5a1fcdfaf2
# Query done.
# Processed: 791.3 MB Billed: 792.0 MB
# Query done.
# Processed: 791.3 MB Billed: 792.0 MB
# Standard price: $0.00 USD
#
# Standard price: $0.00 USD
#
# Downloading: 100%|██████████████████████████████| 5/5 [00:00<00:00, 27.14rows/s]
# Got 5 rows.
#
# Got 5 rows.
#                              doi  \
# 0  10.1016/s0140-6736(20)30183-5
# 1          10.1056/nejmoa2002032
# 2          10.1056/nejmoa2001017
# 3  10.1016/s0140-6736(20)30566-3
# 4         10.1001/jama.2020.1585
#
#                                            pub_title  \
# 0  Clinical features of patients infected with 20...
# 1  Clinical Characteristics of Coronavirus Diseas...
# 2  A Novel Coronavirus from Patients with Pneumon...
# 3  Clinical course and risk factors for mortality...
# 4  Clinical Characteristics of 138 Hospitalized P...
#
#                      journal_title  year volume  issue          pages  \
# 0                       The Lancet  2020    395  10223        497-506
# 1  New England Journal of Medicine  2020    382     18  nejmoa2002032
# 2  New England Journal of Medicine  2020    382      8        727-733
# 3                       The Lancet  2020    395  10229      1054-1062
# 4                             JAMA  2020    323     11      1061-1069
#
#    altmetrics_score  times_cited  field_citation_ratio
# 0             14459        29352              23249.07
# 1             10119        18648              14770.67
# 2              8074        17110               6730.19
# 3             13141        16964              10830.36
# 4              6461        15411              12206.71

# %%
# Get the concepts for publications
sql = """
select
    id,
    year, -- get the year so that we can position these over time
    STRING_AGG(c.concept, ',') as concepts -- so we unnest and aggregate, getting rid of the ectra "relevance" tag and other structure info that will add to the download
  from `covid-19-dimensions-ai.data.publications`,
  unnest(concepts) c
  where type = "article"
  and (LOWER(c.concept) IN UNNEST(["covid-19", "new coronavirus", "novel coronavirus", "sars-cov-2", "2019-ncov", "hcov", "hcov-2019", "severe acute respiratory syndrome coronavirus 2", "coronavirus disease 2019"])
    OR REGEXP_CONTAINS(title.preferred, r"covid-19|new coronavirus|novel coronavirus|sars-cov-2|2019-ncov|hcov|severe acute respiratory syndrome coronavirus|coronavirus disease 2019"))
  group by id;
"""
df = pandas_gbq.read_gbq(sql, project_id=project_id)
df

# Rank by each metric for all
# GLobal, corresponidng authors only'
# US-only, all authorships
# US-only, correpsonding authors only
# Out:
# Requesting query...
# Requesting query...
# Query running...
# Query running...
# Job ID: 738ace65-3faf-489c-b5fa-0789ed7e64a0
# Job ID: 738ace65-3faf-489c-b5fa-0789ed7e64a0
# Query done.
# Processed: 722.2 MB Billed: 723.0 MB
# Query done.
# Processed: 722.2 MB Billed: 723.0 MB
# Standard price: $0.00 USD
#
# Standard price: $0.00 USD
#
# Downloading: 100%|█████████████████| 245698/245698 [00:06<00:00, 35668.29rows/s]
# Got 245698 rows.
#
# Got 245698 rows.
#
# Total time taken 10.58 s.
# Finished at 2022-04-27 12:17:31.
# Total time taken 10.58 s.
# Finished at 2022-04-27 12:17:31.
#                     id                                           concepts
# 0       pub.1137433808  COVID-19,coronavirus pandemic,pandemic,survey,...
# 1       pub.1132948372  COVID-19,la pandemia COVID-19,urgencias,pandem...
# 2       pub.1128243460  coronavirus disease 2019,disease 2019,communit...
# 3       pub.1125649641  coronavirus disease 2019,disease 2019,sepsis,a...
# 4       pub.1135467328  cardiac magnetic resonance findings,epicardial...
# ...                ...                                                ...
# 245693  pub.1130871505  SARS-CoV-2,severe acute respiratory syndrome c...
# 245694  pub.1141113182  SARS-CoV-2,severe acute respiratory syndrome c...
# 245695  pub.1142723603  SARS-CoV-2,severe acute respiratory syndrome c...
# 245696  pub.1143639117  SARS-CoV-2,severe acute respiratory syndrome c...
# 245697  pub.1132540654  SARS-CoV-2,severe acute respiratory syndrome c...
#
# [245698 rows x 2 columns]

# %%
# Get the research organizations 
sql = """
select 
  base.*,
  orgs.name, 
  orgs.types,
  orgs.address.country,
  orgs.address.city,
  orgs_child.name as child_org_name
  from (
    select 
      grant_id,
      grants.funder_org, 
      grants.title,
      grants.funder_org as child_org,
      CASE WHEN hierarchy.parent_id is null THEN grants.funder_org ELSE hierarchy.parent_id END as org_id,
      grants.funding_amount
    from `covid-19-dimensions-ai.data.publications` as pubs
    cross join unnest(supporting_grant_ids) as grant_id
    left join `covid-19-dimensions-ai.data.grants` as grants on grants.id = grant_id
    left join (
      -- get the organizations
      SELECT
        g.id as child_id,
        children.id as parent_id
      FROM
        `covid-19-dimensions-ai.data.grid` g
      CROSS JOIN
        UNNEST(relationships) AS children
      WHERE children.type = "Parent"
    ) as hierarchy on hierarchy.child_id = grants.funder_org
    where pubs.type = "article"
    AND ('COVID-19' in UNNEST(pubs.concepts.concept) or "new coronavirus" in UNNEST(pubs.concepts.concept) or "SARS-CoV-2" in UNNEST(pubs.concepts.concept)
              OR 'ncov' in UNNEST(pubs.concepts.concept) or "novel coronavirus" in UNNEST(pubs.concepts.concept) or "2019-ncov" in UNNEST(pubs.concepts.concept)
              OR "severe acute respiratory syndrome coronavirus" in UNNEST(pubs.concepts.concept) or 'coronavirus disease 2019' in UNNEST(pubs.concepts.concept)
              OR REGEXP_CONTAINS(pubs.title.preferred, r"covid-19|new coronavirus|novel coronavirus|sars-cov-2|2019-ncov|hcov|severe acute respiratory syndrome coronavirus|coronavirus disease 2019"))
    AND funder_org is not Null
) as base 
left join `covid-19-dimensions-ai.data.grid` as orgs on orgs.id = org_id
left join `covid-19-dimensions-ai.data.grid` as orgs_child on orgs_child.id = child_org
where orgs.name is not Null AND funder_org is not Null;
"""
df = pandas_gbq.read_gbq(sql, project_id=project_id)
df
# Out:
# Requesting query...
# Requesting query...
# Query running...
# Query running...
# Job ID: 7af37789-e17b-4f9d-921e-f4f84d6f87c7
# Job ID: 7af37789-e17b-4f9d-921e-f4f84d6f87c7
# Query done.
# Processed: 715.0 MB Billed: 715.0 MB
# Query done.
# Processed: 715.0 MB Billed: 715.0 MB
# Standard price: $0.00 USD
#
# Standard price: $0.00 USD
#
# Downloading: 100%|██████████████████████| 2978/2978 [00:00<00:00, 6095.75rows/s]
# Got 2978 rows.
#
# Got 2978 rows.
#            grant_id     funder_org  \
# 0     grant.9343181  grid.426413.6
# 1     grant.9845960  grid.281076.a
# 2     grant.9846032  grid.416868.5
# 3     grant.9453205  grid.453115.7
# 4     grant.9959631  grid.473834.f
# ...             ...            ...
# 2973  grant.9535866  grid.420089.7
# 2974  grant.9535863  grid.420089.7
# 2975  grant.9535864  grid.420089.7
# 2976  grant.9535863  grid.420089.7
# 2977  grant.9535861  grid.420089.7
#
#                                                   title      child_org  \
# 0     When pandemic and everyday ethics collide: sup...  grid.426413.6
# 1     Leveraging community health workers to improve...  grid.281076.a
# 2     Sex specific immune response to SARS-CoV-2 lea...  grid.416868.5
# 3     Development of Nanopore Sequencing-based Platf...  grid.453115.7
# 4     Measurement of the Aerosol Generating Potentia...  grid.473834.f
# ...                                                 ...            ...
# 2973  Identifying biomarker signatures of prognostic...  grid.420089.7
# 2974  AICORE-kids: Artificial Intelligence COVID-19 ...  grid.420089.7
# 2975             Diagnosis of MIS-C in febrile children  grid.420089.7
# 2976  AICORE-kids: Artificial Intelligence COVID-19 ...  grid.420089.7
# 2977  Diagnosing and predicting risk in children wit...  grid.420089.7
#
#              org_id  funding_amount                                    name  \
# 0     grid.496779.2        258812.0              UK Research and Innovation
# 1     grid.94365.3d        751585.0           National Institutes of Health
# 2     grid.94365.3d        766078.0           National Institutes of Health
# 3     grid.453115.7       1860470.0    Innovation and Technology Commission
# 4     grid.451056.3        399470.0  National Institute for Health Research
# ...             ...             ...                                     ...
# 2973  grid.94365.3d       1685063.0           National Institutes of Health
# 2974  grid.94365.3d       1595976.0           National Institutes of Health
# 2975  grid.94365.3d       1750391.0           National Institutes of Health
# 2976  grid.94365.3d       1595976.0           National Institutes of Health
# 2977  grid.94365.3d       1356336.0           National Institutes of Health
#
#              types         country       city  \
# 0     [Government]  United Kingdom    Swindon
# 1     [Government]   United States   Bethesda
# 2     [Government]   United States   Bethesda
# 3     [Government]           China  Hong Kong
# 4     [Government]  United Kingdom     London
# ...            ...             ...        ...
# 2973  [Government]   United States   Bethesda
# 2974  [Government]   United States   Bethesda
# 2975  [Government]   United States   Bethesda
# 2976  [Government]   United States   Bethesda
# 2977  [Government]   United States   Bethesda
#
#                                          child_org_name
# 0                  Arts and Humanities Research Council
# 1     National Institute on Minority Health and Heal...
# 2                   National Institute of Mental Health
# 3                  Innovation and Technology Commission
# 4                                          NIHR Academy
# ...                                                 ...
# 2973  Eunice Kennedy Shriver National Institute of C...
# 2974  Eunice Kennedy Shriver National Institute of C...
# 2975  Eunice Kennedy Shriver National Institute of C...
# 2976  Eunice Kennedy Shriver National Institute of C...
# 2977  Eunice Kennedy Shriver National Institute of C...
#
# [2978 rows x 11 columns]

# %%
# Get the publications over time & data that I'm interested in working with
sql = """
select 
  ARRAY_CONCAT_AGG(pubs.research_org_countries) as countries,
  ARRAY_CONCAT_AGG(pubs.research_org_state_codes) as states,
  ANY_VALUE(DATE_TRUNC(SAFE_CAST(pubs.date_online AS DATE), MONTH)) as published_date,
  STRING_AGG(c.name, ",") as fields,
  ANY_VALUE(journal.title) as journal_title, -- the title of the journal
  ANY_VALUE(metrics.times_cited) as times_cited,
  ANY_VALUE(altmetrics.score) as altmetrics_score
  from `covid-19-dimensions-ai.data.publications` as pubs, 
  unnest(category_for.second_level.full) c
  where pubs.type = "article"
  AND ('COVID-19' in UNNEST(pubs.concepts.concept) or "new coronavirus" in UNNEST(pubs.concepts.concept) or "SARS-CoV-2" in UNNEST(pubs.concepts.concept)
       OR 'ncov' in UNNEST(pubs.concepts.concept) or "novel coronavirus" in UNNEST(pubs.concepts.concept) or "2019-ncov" in UNNEST(pubs.concepts.concept)
       OR "severe acute respiratory syndrome coronavirus" in UNNEST(pubs.concepts.concept) or 'coronavirus disease 2019' in UNNEST(pubs.concepts.concept)
       OR REGEXP_CONTAINS(pubs.title.preferred, r"covid-19|new coronavirus|novel coronavirus|sars-cov-2|2019-ncov|hcov|severe acute respiratory syndrome coronavirus|coronavirus disease 2019"))
  group by (pubs.id)
"""
df = pandas_gbq.read_gbq(sql, project_id=project_id)
df
# Out:
# Requesting query...
# Requesting query...
# Query running...
# Query running...
# Job ID: c6d75dfb-c52c-484e-9e25-1f3d67e2c62f
# Job ID: c6d75dfb-c52c-484e-9e25-1f3d67e2c62f
# Query done.
# Processed: 799.9 MB Billed: 800.0 MB
# Query done.
# Processed: 799.9 MB Billed: 800.0 MB
# Standard price: $0.00 USD
#
# Standard price: $0.00 USD
#
# Downloading: 100%|█████████████████| 213197/213197 [00:18<00:00, 11740.13rows/s]
# Got 213197 rows.
#
# Got 213197 rows.
#
# Total time taken 24.9 s.
# Finished at 2022-04-27 20:35:16.
# Total time taken 24.9 s.
# Finished at 2022-04-27 20:35:16.
#        countries          states published_date  \
# 0       [US, US]  [US-CO, US-CO]     2022-12-01
# 1           [FR]              []     2020-02-01
# 2           [US]         [US-MA]     2020-01-01
# 3             []              []     2020-02-01
# 4       [CN, CN]              []     2020-02-01
# ...          ...             ...            ...
# 213192      [AU]        [AU-VIC]     2021-03-01
# 213193  [DK, NO]              []     2021-03-01
# 213194      [CN]              []     2021-03-01
# 213195  [US, IT]  [US-GA, US-NY]     2021-03-01
# 213196        []              []     2021-03-01
#
#                                                    fields  \
# 0            Statistics,Public Health and Health Services
# 1                                       Clinical Sciences
# 2                                       Clinical Sciences
# 3                                       Clinical Sciences
# 4       Clinical Sciences,Public Health and Health Ser...
# ...                                                   ...
# 213192                  Public Health and Health Services
# 213193                  Public Health and Health Services
# 213194                                         Psychology
# 213195                  Public Health and Health Services
# 213196                  Public Health and Health Services
#
#                                             journal_title  times_cited  \
# 0                                            Epidemiology            0
# 1                        Plastic & Reconstructive Surgery            2
# 2                         New England Journal of Medicine         4202
# 3       Chinese Journal of Otolaryngology Head and Nec...            3
# 4                           Chinese Journal of Pediatrics           88
# ...                                                   ...          ...
# 213192                                          Nutrients            1
# 213193           Scandinavian Journal of Gastroenterology            2
# 213194                       Psychology Health & Medicine            5
# 213195                    Journal of Health Communication           11
# 213196           Pakistan Journal of Surgery and Medicine            0
#
#         altmetrics_score
# 0                      6
# 1                   <NA>
# 2                  10149
# 3                   <NA>
# 4                    553
# ...                  ...
# 213192                 1
# 213193              <NA>
# 213194              <NA>
# 213195                23
# 213196              <NA>
#
# [213197 rows x 7 columns]
